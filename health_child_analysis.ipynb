# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir(df)
# Out:
# ['Sex',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
df=pd.read_csv("health_child.csv")

# %%
df
# Out:
#      Child participated in POLIO campaign August 2013  diarrhea_status  \
# 0                                                   1               No
# 1                                                   1               No
# 2                                                   1               No
# 3                                                   1               No
# 4                                                   1               No
# ..                                                ...              ...
# 794                                                 1               No
# 795                                                 2               No
# 796                                                 1               No
# 797                                                 1               No
# 798                                                 1               No
#
#      weight  height residence     Sex  age age_category   education  \
# ...

# %%
df.head(100)
# Out:
#     Child participated in POLIO campaign August 2013  diarrhea_status  weight  \
# 0                                                  1               No    16.2
# 1                                                  1               No    13.5
# 2                                                  1               No    13.4
# 3                                                  1               No    15.0
# 4                                                  1               No    15.2
# ..                                               ...              ...     ...
# 95                                                 1               No    13.2
# 96                                                 1               No     8.9
# 97                                                 1               No     8.7
# 98                                                 1               No     7.8
# 99                                                 1               No    10.6
#
# ...

# %%
df.tail()
# Out:
#      Child participated in POLIO campaign August 2013  diarrhea_status  \
# 794                                                 1               No
# 795                                                 2               No
# 796                                                 1               No
# 797                                                 1               No
# 798                                                 1               No
#
#      weight  height residence     Sex  age age_category   education  \
# 794     8.3    67.0     Urban  Female    7       06-Nov     Primary
# 795     3.5    45.0     Urban    Male    0          0-5  Secondary+
# 796    15.1    86.0     Urban  Female   56        48-59     Primary
# 797    10.7    71.2     Urban  Female   18       Dec-23     Primary
# 798    10.3    73.0     Urban  Female    7       06-Nov     Primary
#
#     wealth_index
# 794       Fourth
# 795       Fourth
# 796       Fourth
# 797       Fourth
# 798       Middle

# %%
df.columns
# Out:
# Index(['Child participated in POLIO campaign August 2013', ' diarrhea_status',
#        'weight', 'height', 'residence', 'Sex', 'age', 'age_category',
#        'education', 'wealth_index'],
#       dtype='object')

# %%
df.shape
# Out:
# (799, 10)

# %%
df.describe()
# Out:
#        Child participated in POLIO campaign August 2013      weight  \
# count                                        799.000000  799.000000
# mean                                           1.234043   11.591114
# std                                            0.850500    3.408729
# min                                            1.000000    3.100000
# 25%                                            1.000000    9.200000
# 50%                                            1.000000   11.700000
# 75%                                            1.000000   14.100000
# max                                            9.000000   25.000000
#
#            height         age
# count  799.000000  799.000000
# mean    83.858573   29.314143
# std     13.795704   16.839659
# min     45.000000    0.000000
# 25%     74.000000   15.000000
# 50%     84.900000   31.000000
# 75%     93.850000   43.000000
# max    124.800000   59.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Child participated in POLIO campaign August 2013  799 non-null    int64
#  1    diarrhea_status                                  799 non-null    object
#  2   weight                                            799 non-null    float64
#  3   height                                            799 non-null    float64
#  4   residence                                         799 non-null    object
#  5   Sex                                               799 non-null    object
#  6   age                                               799 non-null    int64
#  7   age_category                                      799 non-null    object
#  8   education                                         768 non-null    object
# ...

# %%
gender=df["Sex"].value_counts()
gender
# Out:
# Sex
# Male      401
# Female    398
# Name: count, dtype: int64

# %%
gender.plot(
    kind="pie"
    
    
);

# %%
residence=df["residence"].value_counts()
residence
# Out:
# residence
# Rural    453
# Urban    346
# Name: count, dtype: int64

# %%
residence.plot(
    kind="bar"
    
);

# %%
plt.scatter(x=df["height"],y=df["weight"],color="g"),
plt.xlabel("height"),
plt.ylabel("weight")
plt.legend()
plt.show();
# Out:
# C:\Users\sheikh\AppData\Local\Temp\ipykernel_16108\706936099.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df["height"].corr(df["weight"])
# Out:
# 0.8813619146353242

# %%
subset_num_data=(df[["weight","age","height"]])

# %%
subset_num_data
# Out:
#      weight  age  height
# 0      16.2   45   102.4
# 1      13.5   45    92.5
# 2      13.4   36    88.5
# 3      15.0   51   101.3
# 4      15.2   56   105.0
# ..      ...  ...     ...
# 794     8.3    7    67.0
# 795     3.5    0    45.0
# 796    15.1   56    86.0
# 797    10.7   18    71.2
# 798    10.3    7    73.0
#
# [799 rows x 3 columns]

# %%
subset_num_data.corr()
# Out:
#           weight       age    height
# weight  1.000000  0.831354  0.881362
# age     0.831354  1.000000  0.870534
# height  0.881362  0.870534  1.000000

# %%
df[df["age"]<10]
# Out:
#      Child participated in POLIO campaign August 2013  diarrhea_status  \
# 6                                                   2               No
# 14                                                  1               No
# 16                                                  1               No
# 25                                                  2               No
# 27                                                  1               No
# ..                                                ...              ...
# 789                                                 2               No
# 790                                                 2               No
# 794                                                 1               No
# 795                                                 2               No
# 798                                                 1               No
#
#      weight  height residence     Sex  age age_category   education  \
# ...

# %%
df[df["age"]<10].value_counts()
# Out:
# Child participated in POLIO campaign August 2013   diarrhea_status  weight  height  residence  Sex     age  age_category  education   wealth_index
# 1                                                 No                4.2     68.5    Rural      Male    6    06-Nov        Primary     Second          1
# 2                                                 No                5.7     61.6    Urban      Female  3    0-5           Primary     Poorest         1
#                                                                     4.9     57.0    Rural      Female  2    0-5           Secondary+  Richest         1
#                                                                             60.3    Rural      Female  1    0-5           Primary     Poorest         1
#                                                                     5.2     51.0    Rural      Male    0    0-5           Primary     Second          1
# ...

# %%
df[df['Sex']=='Male']
# Out:
#      Child participated in POLIO campaign August 2013  diarrhea_status  \
# 1                                                   1               No
# 2                                                   1               No
# 7                                                   1               No
# 8                                                   1               No
# 11                                                  1              Yes
# ..                                                ...              ...
# 786                                                 2               No
# 788                                                 2               No
# 790                                                 2               No
# 792                                                 1               No
# 795                                                 2               No
#
#      weight  height residence   Sex  age age_category   education wealth_index
# ...

# %%
df[df['Sex']=='Male'].value_counts()
# Out:
# Child participated in POLIO campaign August 2013   diarrhea_status  weight  height  residence  Sex   age  age_category  education   wealth_index
# 1                                                 No                4.2     68.5    Rural      Male  6    06-Nov        Primary     Second          1
#                                                                     16.5    87.0    Rural      Male  33   24-35         Primary     Second          1
#                                                                     17.0    105.3   Urban      Male  59   48-59         Secondary+  Richest         1
#                                                                             103.5   Rural      Male  44   36-47         Primary     Richest         1
#                                                                     16.9    106.4   Urban      Male  59   48-59         Secondary+  Second          1
# ...

# %%
#drop missing values
df.dropna(inplace=True)
